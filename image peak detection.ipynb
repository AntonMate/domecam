# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage.filters import maximum_filter
from scipy.ndimage.morphology import generate_binary_structure, binary_erosion

# https://stackoverflow.com/questions/3684484/peak-detection-in-a-2d-array
img = np.loadtxt("D:/astro/domecam/data/20210130l_m2km_corr_4.gz")

plt.figure()
plt.imshow(img)

neighborhood = generate_binary_structure(2, 1)
local_max = maximum_filter(img, footprint=neighborhood)==img
background = (img==0)
eroded_background = binary_erosion(background, structure=neighborhood, border_value=1)
detected_peaks = local_max ^ eroded_background

plt.figure()
plt.imshow(detected_peaks)
plt.colorbar()

# %%
import matplotlib.pyplot as plt
import numpy as np

img = np.loadtxt("D:/astro/domecam/data/20210130l_m2km_corr_4.gz")

xx, yy = np.mgrid[0:img.shape[0], 0:img.shape[1]]

fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_surface(xx, yy, img, rstride=3, cstride=3, linewidth=0, cmap='gray')
# Out:
# C:\Users\miron\AppData\Local\Temp\ipykernel_84\1256643408.py:9: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')
